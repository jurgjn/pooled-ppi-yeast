# %%
import pandas as pd

# %%
pd.read_parquet('../data/predictions/alphafold3_summary_confidences.parquet').head(2).transpose()
# Out:
#                                                                           0  \
# name                               00057fce464a9de2ec699af7e721648b272b078a
# seed                                                                      4
# sample                                                                    0
# ranking_score                                                      0.326816
# fraction_disordered                                                    0.02
# has_clash                                                               0.0
# iptm                                                                    0.3
# ptm                                                                    0.39
# chain_iptm                [0.1, 0.18, 0.09, 0.17, 0.08, 0.09, 0.08, 0.09...
# chain_pair_iptm           [[0.16, 0.17, 0.09, 0.15, 0.06, 0.07, 0.06, 0....
# chain_pair_pae_min        [[0.76, 29.74, 26.31, 30.63, 30.44, 30.67, 30....
# ...

# %%
pd.read_parquet('../data/predictions/alphafold3_summary_pairs.parquet').head(2).transpose()
# Out:
#                                                                          0  \
# name                              0000e33a0eab4a1d137c732ccacef998d3b1b2cd
# batch_id                                           26.02/euler-std-a100-r3
# chain_pair_iptm_best                                                  0.15
# chain_pair_iptm_mean                                                  0.15
# af3_pair                                                     p31382_p34110
# af3_id1                                                             p31382
# af3_id2                                                             p34110
# seq_len1                                                               759
# seq_len2                                                               944
# pair_len                                                              1703
# string_protein1
# string_protein2
# string_neighborhood                                                      0
# ...
